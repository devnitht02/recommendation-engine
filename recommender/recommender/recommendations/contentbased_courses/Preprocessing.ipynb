# %%
import torch
from sentence_transformers import SentenceTransformer
import pandas as pd
import json

# %% [markdown]
# ## Load data Set

# %%
df = pd.read_csv("../DataSets/processed/course_content_based_data_after_eda.csv",sep=";",header=0)

# %%
df.head()
# Out:
#    id             course_names  \
# 0   1   Accounting and Finance
# 1   1             Biochemistry
# 2   1  Business Administration
# 3   1    Computer Applications
# 4   1         Computer Science
#
#                              all_course_descriptions  \
# 0  Bachelor of Commerce (BCom) degree with a focu...
# 1  Bachelor of Science (BSc) in Biochemistry prov...
# 2  Bachelor of Business Administration (BBA) in B...
# 3  Bachelor of Commerce (BCom) program with a spe...
# 4  Bachelor of Science (BSc) in Computer Science ...
#
#                              all_degree_descriptions all_stream_names  \
# 0                               Bachelor of Commerce            B.Com
# 1                Bachelor of Science (3years) - B.Sc             B.Sc
# 2                Bachelor of Business Administration              BBA
# 3  Bachelor of Commerce, Bachelor of Computer App...       B.Com, BCA
# 4                Bachelor of Science (3years) - B.Sc             B.Sc
#
#     all_degree_names
# ...

# %% [markdown]
# Load model for embedding

# %%
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# %%
df.head()
# Out:
#    id             course_names  \
# 0   1   Accounting and Finance
# 1   1             Biochemistry
# 2   1  Business Administration
# 3   1    Computer Applications
# 4   1         Computer Science
#
#                              all_course_descriptions  \
# 0  Bachelor of Commerce (BCom) degree with a focu...
# 1  Bachelor of Science (BSc) in Biochemistry prov...
# 2  Bachelor of Business Administration (BBA) in B...
# 3  Bachelor of Commerce (BCom) program with a spe...
# 4  Bachelor of Science (BSc) in Computer Science ...
#
#                              all_degree_descriptions all_stream_names  \
# 0                               Bachelor of Commerce            B.Com
# 1                Bachelor of Science (3years) - B.Sc             B.Sc
# 2                Bachelor of Business Administration              BBA
# 3  Bachelor of Commerce, Bachelor of Computer App...       B.Com, BCA
# 4                Bachelor of Science (3years) - B.Sc             B.Sc
#
#     all_degree_names
# ...

# %%
df["combined_text"] = df[
    ["all_course_descriptions", "all_degree_descriptions", "all_degree_names", 
     "all_stream_names", "course_names"]
].astype(str).agg(" ".join, axis=1)

# %%
df.head()
# Out:
#    id             course_names  \
# 0   1   Accounting and Finance
# 1   1             Biochemistry
# 2   1  Business Administration
# 3   1    Computer Applications
# 4   1         Computer Science
#
#                              all_course_descriptions  \
# 0  Bachelor of Commerce (BCom) degree with a focu...
# 1  Bachelor of Science (BSc) in Biochemistry prov...
# 2  Bachelor of Business Administration (BBA) in B...
# 3  Bachelor of Commerce (BCom) program with a spe...
# 4  Bachelor of Science (BSc) in Computer Science ...
#
#                              all_degree_descriptions all_stream_names  \
# 0                               Bachelor of Commerce            B.Com
# 1                Bachelor of Science (3years) - B.Sc             B.Sc
# 2                Bachelor of Business Administration              BBA
# 3  Bachelor of Commerce, Bachelor of Computer App...       B.Com, BCA
# 4                Bachelor of Science (3years) - B.Sc             B.Sc
#
# ...

# %%
df["embeddings"] = df["combined_text"].apply(lambda x: model.encode(x))

# %%
df.head()
# Out:
#    id             course_names  \
# 0   1   Accounting and Finance
# 1   1             Biochemistry
# 2   1  Business Administration
# 3   1    Computer Applications
# 4   1         Computer Science
#
#                              all_course_descriptions  \
# 0  Bachelor of Commerce (BCom) degree with a focu...
# 1  Bachelor of Science (BSc) in Biochemistry prov...
# 2  Bachelor of Business Administration (BBA) in B...
# 3  Bachelor of Commerce (BCom) program with a spe...
# 4  Bachelor of Science (BSc) in Computer Science ...
#
#                              all_degree_descriptions all_stream_names  \
# 0                               Bachelor of Commerce            B.Com
# 1                Bachelor of Science (3years) - B.Sc             B.Sc
# 2                Bachelor of Business Administration              BBA
# 3  Bachelor of Commerce, Bachelor of Computer App...       B.Com, BCA
# 4                Bachelor of Science (3years) - B.Sc             B.Sc
#
# ...

# %%
df["embeddings"] = df["embeddings"].apply(lambda x: ",".join(map(str, x)))

# %%
df.to_csv("../DataSets/processed/courses_content_based_data_after_eda_after_embedding.csv",index=False,sep=";")
